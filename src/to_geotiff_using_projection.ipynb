# %%
import rioxarray
import xarray
from pyproj import CRS

# %%
xds = xarray.open_dataset("/home/asubedi/Desktop/data/raw-files/GLM/OR_GLM-L3-GLMF-M6_G16_s202315823490000_e202315823500000_c20231582351080.nc")
cc = CRS.from_cf(xds.goes_imager_projection.attrs)
xds = xds.squeeze().transpose('y', 'x')
xds.coords["x"] = xds.x
xds.coords["y"] = xds.y
xds
# xds.coords["goes_imager_projection"] = xds.goes_imager_projection
# xds.rio.write_crs(cc.to_string(), inplace=True)
# sat_height = xds.goes_imager_projection.attrs["perspective_point_height"]
# x_values = xds.x.values * sat_height
# y_values = xds.y.values * sat_height
# xds = xds.assign_coords(x=x_values)
# xds = xds.assign_coords(y=x_values)
# Out:
# <xarray.Dataset>
# Dimensions:                 (x: 5424, y: 5424)
# Coordinates:
#   * x                       (x) float32 -0.1518 -0.1518 ... 0.1518 0.1518
#   * y                       (y) float32 0.1518 0.1518 0.1517 ... -0.1518 -0.1518
# Data variables:
#     Flash_extent_density    (y, x) float32 ...
#     Total_Optical_energy    (y, x) float32 ...
#     Minimum_flash_area      (y, x) float32 ...
#     DQF                     (y, x) float32 ...
#     goes_imager_projection  int32 ...
# Attributes: (12/31)
#     cdm_data_type:             Image
#     Conventions:               CF-1.7
#     dataset_name:              OR_GLMFD-020-B16-M0C00-T030_G16_s2023158234900...
#     id:                        93cb84a3-31ef-4823-89f5-c09d88fc89e8
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     instrument_ID:             GLM-1
#     ...                        ...
#     time_coverage_start:       2023-06-07T23:49:00Z
#     timeline_id:               ABI Mode 6
#     title:                     GLM L2 Lightning Detection Gridded Product
#     mission_name:              GLM_plot
#     tile_row_offset:           2428
#     tile_column_offset:        1808

# %%
xds = xds['Flash_extent_density']

# %%
xds
# Out:
# <xarray.DataArray 'Flash_extent_density' (y: 5424, x: 5424)>
# [29419776 values with dtype=float32]
# Coordinates:
#   * x                       (x) float32 -5.434e+06 -5.432e+06 ... 5.434e+06
#   * y                       (y) float32 -5.434e+06 -5.432e+06 ... 5.434e+06
#     goes_imager_projection  int64 0
# Attributes:
#     standard_name:  Flash Extent Density
#     long_name:      GLM Flash Extent Density
#     grid_mapping:   goes_imager_projection
#     valid_min:      0
#     valid_max:      50

# %%
xds_lonlat = xds.rio.reproject("EPSG:4326")
# Out:
# ---------------------------------------------------------------------------
# CPLE_BaseError                            Traceback (most recent call last)
# File rasterio/crs.pyx:775, in rasterio.crs.CRS.from_user_input()
#
# File rasterio/_err.pyx:205, in rasterio._err.exc_wrap_ogrerr()
#
# CPLE_BaseError: OGR Error code 6
#
# During handling of the above exception, another exception occurred:
#
# CRSError                                  Traceback (most recent call last)
# Cell In [65], line 1
# ----> 1 xds_lonlat = xds.rio.reproject("EPSG:4326")
#
# File ~/.local/lib/python3.8/site-packages/rioxarray/raster_array.py:449, in RasterArray.reproject(self, dst_crs, resolution, shape, transform, resampling, nodata, **kwargs)
#     447 src_affine = None if gcps_or_rpcs else self.transform(recalc=True)
#     448 if transform is None:
# --> 449     dst_affine, dst_width, dst_height = _make_dst_affine(
#     450         self._obj, self.crs, dst_crs, resolution, shape, **kwargs
#     451     )
#     452 else:
#     453     dst_affine = transform
#
# File ~/.local/lib/python3.8/site-packages/rioxarray/raster_array.py:155, in _make_dst_affine(src_data_array, src_crs, dst_crs, dst_resolution, dst_shape, **kwargs)
#     153     if value is not None:
#     154         kwargs[key] = value
# --> 155 dst_affine, dst_width, dst_height = rasterio.warp.calculate_default_transform(
#     156     src_crs,
#     157     dst_crs,
#     158     src_width,
#     159     src_height,
#     160     *src_bounds,
#     161     **kwargs,
#     162 )
#     163 return dst_affine, dst_width, dst_height
#
# File ~/.local/lib/python3.8/site-packages/rasterio/env.py:392, in ensure_env.<locals>.wrapper(*args, **kwds)
#     390 else:
#     391     with Env.from_defaults():
# --> 392         return f(*args, **kwds)
#
# File ~/.local/lib/python3.8/site-packages/rasterio/warp.py:488, in calculate_default_transform(src_crs, dst_crs, width, height, left, bottom, right, top, gcps, rpcs, resolution, dst_width, dst_height, **kwargs)
#     485 if resolution and dimensions:
#     486     raise ValueError("Resolution cannot be used with dst_width and dst_height.")
# --> 488 dst_affine, dst_width, dst_height = _calculate_default_transform(
#     489     src_crs, dst_crs, width, height, left, bottom, right, top, gcps, rpcs, **kwargs
#     490 )
#     492 # If resolution is specified, Keep upper-left anchored
#     493 # adjust the transform resolutions
#     494 # adjust the width/height by the ratio of estimated:specified res (ceil'd)
#     495 if resolution:
#     496     # resolutions argument into tuple
#
# File rasterio/_warp.pyx:646, in rasterio._warp._calculate_default_transform()
#
# File rasterio/crs.pyx:777, in rasterio.crs.CRS.from_user_input()
#
# CRSError: The WKT could not be parsed. OGR Error code 6
